# %%
import postprocessing_configurations

# %%
# Himalaya 0102
multi_config = {
    'main_dir': '/home/jberg/OneDrive/Raven_worldwide',
#    'glogem_dir': '/home/jberg/OneDrive/Raven_Switzerland/01_data/GloGEM/GloGEM_output_{gauge_id}.dat',
    'raven_executable': '/home/jberg/OneDrive/RavenHydro/build/Raven',
    'gauge_id': '0102',
    'start_date': '1980-01-01',
    'end_date': '2010-12-31',
    'cali_end_date': '1995-12-31',
    'model_type': 'HBV',
    'configs': [
        "03_model_setups_gmb",
        "03_model_setups_gmb_har",
        "03_model_setups_snowline",
        "03_model_setups_snowline_har",
        "03_model_setups_snowline_update",
        "03_model_setups_snowline_update_har",
    ],
    'config_colors': {
        '03_model_setups_gmb': '#712423',
        '03_model_setups_gmb_har': '#976c03',
        '03_model_setups_snowline': '#82b182',
        '03_model_setups_snowline_har': '#3b528b',
        '03_model_setups_snowline_update': '#b35806',
        '03_model_setups_snowline_update_har': '#1f968b',
    },
    'config_names': {
        '03_model_setups_gmb': 'GMB-ERA5',
        '03_model_setups_gmb_har': 'GMB-HAR',
        '03_model_setups_snowline': 'TSLA-ERA5',
        '03_model_setups_snowline_har': 'TSLA-HAR',
        '03_model_setups_snowline_update': 'TSLA-ERA5-new',
        '03_model_setups_snowline_update_har': 'TSLA-HAR-new',
    },
    'config_coupled': {
        '03_model_setups_gmb': True,
        '03_model_setups_gmb_har': True,
        '03_model_setups_snowline': True,
        '03_model_setups_snowline_har': True,
        '03_model_setups_snowline_update': True,
        '03_model_setups_snowline_update_har': True,
    }
}

# %%
# Himalaya 0116
multi_config = {
    'main_dir': '/home/jberg/OneDrive/Raven_worldwide',
#    'glogem_dir': '/home/jberg/OneDrive/Raven_Switzerland/01_data/GloGEM/GloGEM_output_{gauge_id}.dat',
    'raven_executable': '/home/jberg/OneDrive/RavenHydro/build/Raven',
    'gauge_id': '0116',
    'start_date': '1980-01-01',
    'end_date': '1998-12-31',
    'cali_end_date': '1990-12-31',
    'model_type': 'HBV',
    'configs': [
        "03_model_setups_gmb",
        "03_model_setups_gmb_har",
        "03_model_setups_snowline",
        "03_model_setups_snowline_har",
    ],
    'config_colors': {
        '03_model_setups_gmb': '#712423',
        '03_model_setups_gmb_har': '#976c03',
        '03_model_setups_snowline': '#82b182',
        '03_model_setups_snowline_har': '#3b528b',
    },
    'config_names': {
        '03_model_setups_gmb': 'GMB-ERA5',
        '03_model_setups_gmb_har': 'GMB-HAR',
        '03_model_setups_snowline': 'TSLA-ERA5',
        '03_model_setups_snowline_har': 'TSLA-HAR',
    },
    'config_coupled': {
        '03_model_setups_gmb': True,
        '03_model_setups_gmb_har': True,
        '03_model_setups_snowline': True,
        '03_model_setups_snowline_har': True,
    }
}

# %%
multi_config = {
    'main_dir': '/home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02',
    'raven_executable': '/home/jberg/OneDrive/RavenHydro/build/Raven',
    'gauge_id': '0118',
    'start_date': '1985-01-01',
    'end_date': '1997-12-31',
    'cali_end_date': '1991-12-31',
    'model_type': 'HBV',
    'configs': [
        "03_model_setups_gmb",
        "03_model_setups_gmb_prec",
        "03_model_setups_gmb_har",
        "03_model_setups_gmb_har_prec",
        "03_model_setups_snowline",
        "03_model_setups_snowline_prec",
        "03_model_setups_raven",
        "03_model_setups_raven_prec",
    ],
    'config_colors': {
        '03_model_setups_gmb': '#712423',           # Dark red
        '03_model_setups_gmb_prec': '#c44e52',      # Medium red (NEW)
        '03_model_setups_gmb_har': '#1f968b',       # Dark yellow/gold
        '03_model_setups_gmb_har_prec': '#d4a373',  # Light brown/tan (NEW)
        '03_model_setups_snowline': '#b35806',      # Green
        '03_model_setups_snowline_prec': '#55a868', # Darker green (NEW - alternate)
        '03_model_setups_snowline_har': '#3b528b',  # Dark blue
        '03_model_setups_raven': '#8c564b',         # Brown (NEW)
        '03_model_setups_raven_prec': '#e377c2',    # Pink/magenta (NEW)
    },
    'config_names': {
        '03_model_setups_gmb': 'GMB-ERA5',
        '03_model_setups_gmb_prec': 'GMB-ERA5-PrecCorr',
        '03_model_setups_gmb_har': 'GMB-HAR',
        '03_model_setups_gmb_har_prec': 'GMB-HAR-PrecCorr',
        '03_model_setups_snowline': 'TSLA-ERA5',
        '03_model_setups_snowline_prec': 'TSLA-ERA5-PrecCorr',
        '03_model_setups_raven': 'Raven-ERA5',
        '03_model_setups_raven_prec': 'Raven-ERA5-PrecCorr',
    },
    'config_coupled': {
        '03_model_setups_gmb': True,
        '03_model_setups_gmb_prec': True,
        '03_model_setups_gmb_har': True,
        '03_model_setups_gmb_har_prec': True,
        '03_model_setups_snowline': True,
        '03_model_setups_snowline_prec': True,
        '03_model_setups_raven': False,
        '03_model_setups_raven_prec': False,
    }
}

# %%
multi_config = {
    'main_dir': '/home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02',
    'raven_executable': '/home/jberg/OneDrive/RavenHydro/build/Raven',
    'gauge_id': '0118',
    'start_date': '1985-01-01',
    'end_date': '1997-12-31',
    'cali_end_date': '1991-12-31',
    'model_type': 'HBV',
    'configs': [
        "03_model_setups_gmb",
        "03_model_setups_snowline",
        "03_model_setups_raven",
        "03_model_setups_gmb_prec",
        "03_model_setups_snowline_prec",
        "03_model_setups_raven_prec",
    ],
    'config_colors': {
        '03_model_setups_gmb': '#712423',           # Dark red
        '03_model_setups_gmb_prec': '#1f968b',      # Medium red (NEW)
        '03_model_setups_snowline': '#b35806',      # Green
        '03_model_setups_snowline_prec': '#55a868', # Darker green (NEW - alternate)
        '03_model_setups_snowline_har': '#3b528b',  # Dark blue
        '03_model_setups_raven': '#d4a373',         # Brown (NEW)
        '03_model_setups_raven_prec': '#e377c2',    # Pink/magenta (NEW)
    },
    'config_names': {
        '03_model_setups_gmb': 'GMB-ERA5',
        '03_model_setups_gmb_prec': 'GMB-ERA5-PrecCorr',
        '03_model_setups_snowline': 'TSLA-ERA5',
        '03_model_setups_snowline_prec': 'TSLA-ERA5-PrecCorr',
        '03_model_setups_raven': 'Raven-ERA5',
        '03_model_setups_raven_prec': 'Raven-ERA5-PrecCorr',
    },
    'config_coupled': {
        '03_model_setups_gmb': True,
        '03_model_setups_gmb_prec': True,
        '03_model_setups_snowline': True,
        '03_model_setups_snowline_prec': True,
        '03_model_setups_raven': False,
        '03_model_setups_raven_prec': False,
    }
}

# %%
multi_config = {
    'main_dir': '/home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02',
    'raven_executable': '/home/jberg/OneDrive/RavenHydro/build/Raven',
    'gauge_id': '0102',
    'start_date': '1980-01-01',
    'end_date': '2015-12-31',
    'cali_end_date': '1999-12-31',
    'model_type': 'HBV',
    'configs': [
        "03_model_setups_gmb",
        "03_model_setups_snowline",
        "03_model_setups_raven",
        "03_model_setups_gmb_prec",
        "03_model_setups_snowline_prec",
        "03_model_setups_raven_prec",
    ],
    'config_colors': {
        '03_model_setups_gmb': '#712423',           # Dark red
        '03_model_setups_gmb_prec': '#1f968b',      # Medium red (NEW)
        '03_model_setups_snowline': '#b35806',      # Green
        '03_model_setups_snowline_prec': '#55a868', # Darker green (NEW - alternate)
        '03_model_setups_raven': '#d4a373',         # Brown (NEW)
        '03_model_setups_raven_prec': '#e377c2',    # Pink/magenta (NEW)
    },
    'config_names': {
        '03_model_setups_gmb': 'GMB-ERA5',
        '03_model_setups_gmb_prec': 'GMB-ERA5-PrecCorr',
        '03_model_setups_snowline': 'TSLA-ERA5',
        '03_model_setups_snowline_prec': 'TSLA-ERA5-PrecCorr',
        '03_model_setups_raven': 'Raven-ERA5',
        '03_model_setups_raven_prec': 'Raven-ERA5-PrecCorr',
    },
    'config_coupled': {
        '03_model_setups_gmb': True,
        '03_model_setups_gmb_prec': True,
        '03_model_setups_snowline': True,
        '03_model_setups_snowline_prec': True,
        '03_model_setups_raven': False,
        '03_model_setups_raven_prec': False,
    }
}

# %%
multi_config = {
    'main_dir': '/home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02',
    'raven_executable': '/home/jberg/OneDrive/RavenHydro/build/Raven',
    'gauge_id': '0119',
    'start_date': '1980-01-01',
    'end_date': '1997-12-31',
    'cali_end_date': '1989-12-31',
    'model_type': 'HBV',
    'configs': [
        "03_model_setups_gmb",
        "03_model_setups_raven",
        "03_model_setups_gmb_prec",
        "03_model_setups_raven_prec",
    ],
    'config_colors': {
        '03_model_setups_gmb': '#712423',           # Dark red
        '03_model_setups_gmb_prec': '#1f968b',      # Medium red (NEW)
        '03_model_setups_raven': '#d4a373',         # Brown (NEW)
        '03_model_setups_raven_prec': '#e377c2',    # Pink/magenta (NEW)
    },
    'config_names': {
        '03_model_setups_gmb': 'GMB-ERA5',
        '03_model_setups_gmb_prec': 'GMB-ERA5-PrecCorr',
        '03_model_setups_raven': 'Raven-ERA5',
        '03_model_setups_raven_prec': 'Raven-ERA5-PrecCorr',
    },
    'config_coupled': {
        '03_model_setups_gmb': True,
        '03_model_setups_gmb_prec': True,
        '03_model_setups_raven': False,
        '03_model_setups_raven_prec': False,
    }
}

# %%
# Plot comparison directly
postprocessing_configurations.plot_hydrological_regime_comparison(multi_config)
# Out:
# Creating hydrological regime comparison for 8 configurations:
#   - Catchment: 0118
#   - Validation period: 1991-12-31 to 1997-12-31
# Created multi-configuration plot directory: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/multi_config_plots_catchment_0118
#
# Processing configuration: 03_model_setups_gmb
# Loading hydrograph data:
#   - File: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/03_model_setups_gmb/catchment_0118/HBV/output/0118_HBV_Hydrographs.csv
#   - Found columns: sim=0118 [m3/s], obs=0118 (observed) [m3/s], precip=precip [mm/day]
#   - Data range: 1983-01-02 00:00:00 to 1997-12-31 00:00:00
#   ✓ Loaded simulated data: 12 months
#   ✓ Loaded observed data: 12 months
#   ✓ Performance: NSE=0.698, KGE=0.775
#
# Processing configuration: 03_model_setups_gmb_prec
# Loading hydrograph data:
#   - File: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/03_model_setups_gmb_prec/catchment_0118/HBV/output/0118_HBV_Hydrographs.csv
# ...

# %%
# Plot individual regime subplots for each configuration
config_results_subplots = postprocessing_configurations.plot_hydrological_regime_subplots(multi_config, unit = 'mm')
# Out:
# Creating individual hydrological regime plots for 6 configurations:
#   - Catchment: 0118
#   - Validation period: 1991-12-31 to 1997-12-31
#   - Unit: mm/day
# Created multi-configuration plot directory: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/multi_config_plots_catchment_0118
#
# Processing configuration: 03_model_setups_gmb
# Loading hydrograph data:
#   - File: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/03_model_setups_gmb/catchment_0118/HBV/output/0118_HBV_Hydrographs.csv
#   - Found columns: sim=0118 [m3/s], obs=0118 (observed) [m3/s], precip=precip [mm/day]
#   - Data range: 1983-01-02 00:00:00 to 1997-12-31 00:00:00
#   ✓ Converted discharge to mm/day (catchment area: 6711.30 km²)
#   ✓ Loaded simulated data: 12 months
#   ✓ Loaded observed data: 12 months
#   ✓ Performance: NSE=0.698, KGE=0.775
#
# Processing configuration: 03_model_setups_snowline
# Loading hydrograph data:
# ...

# %%
# Plot hydrograph timeseries for 2 random years
results = postprocessing_configurations.plot_hydrograph_timeseries_comparison(multi_config,n_years=5)
# Out:
# Creating hydrograph timeseries comparison for 8 configurations:
#   - Catchment: 0118
#   - Validation period: 1991-12-31 to 1997-12-31
#   - Number of random years: 5
# Created multi-configuration plot directory: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/multi_config_plots_catchment_0118
#
# Processing configuration: 03_model_setups_gmb
# Loading hydrograph data:
#   - File: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/03_model_setups_gmb/catchment_0118/HBV/output/0118_HBV_Hydrographs.csv
#   - Found columns: sim=0118 [m3/s], obs=0118 (observed) [m3/s], precip=precip [mm/day]
#   - Data range: 1983-01-02 00:00:00 to 1997-12-31 00:00:00
#   ✓ Loaded data with years: [np.int32(1991), np.int32(1992), np.int32(1993), np.int32(1994), np.int32(1995), np.int32(1996), np.int32(1997)]
#
# Processing configuration: 03_model_setups_gmb_prec
# Loading hydrograph data:
# ...

# %%
# Plot SWE timeseries comparison
swe_results = postprocessing_configurations.plot_swe_timeseries_comparison(multi_config)
# Out:
# Creating SWE timeseries comparison for 6 configurations:
#   - Catchment: 0102
#   - Validation period: 1995-12-31 to 2010-12-31
# Created multi-configuration plot directory: /home/jberg/OneDrive/Raven_worldwide/multi_config_plots_catchment_0102
#
# Processing configuration: 03_model_setups_gmb
# Loading SWE data for all HRU groups:
#   - File: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_gmb/catchment_0102/HBV/output/0102_HBV_SNOW_Daily_Average_ByHRUGroup.csv
#   - Loaded data shape: (12052, 71)
# ...

# %%
# Plot SWE elevation bands comparison for validation period
swe_elevation_results = postprocessing_configurations.plot_swe_elevation_bands_comparison(multi_config)
# Out:
# Creating SWE elevation bands comparison for 8 configurations:
#   - Catchment: 0104
#   - Period: Validation Period (1997-12-31 to 2009-12-31)
# Created multi-configuration plot directory: /home/jberg/OneDrive/Raven_worldwide/04_second_Himalaya_runs/multi_config_plots_catchment_0104
#
# Processing configuration: model_setups_base
# Loading SWE data:
#   - Simulated data: /home/jberg/OneDrive/Raven_worldwide/04_second_Himalaya_runs/model_setups_base/catchment_0104/HBV/output/0104_HBV_SNOW_Daily_Average_ByHRUGroup.csv
#   - Observed data: /home/jberg/OneDrive/Raven_worldwide/04_second_Himalaya_runs/model_setups_base/catchment_0104/HBV/data_obs/swe_by_elevation_band.csv
#   - Area data: /home/jberg/OneDrive/Raven_worldwide/04_second_Himalaya_runs/model_setups_base/catchment_0104/HBV/data_obs/elevation_band_areas.csv
#   ✅ Successfully loaded simulated SWE data (10591 records)
# ...

# %%
# Plot streamflow metrics comparison
metrics_results = postprocessing_configurations.plot_streamflow_metrics_comparison(multi_config)
# Out:
# Creating streamflow metrics comparison for 8 configurations:
#   - Catchment: 0118
#   - Validation period: 1991-12-31 to 1997-12-31
# Created multi-configuration plot directory: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/multi_config_plots_catchment_0118
#
# Processing configuration: 03_model_setups_gmb
# Loading hydrograph data:
#   - File: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/03_model_setups_gmb/catchment_0118/HBV/output/0118_HBV_Hydrographs.csv
#   - Found columns: sim=0118 [m3/s], obs=0118 (observed) [m3/s], precip=precip [mm/day]
#   - Data range: 1983-01-02 00:00:00 to 1997-12-31 00:00:00
#   - Working with 2193 valid data points for Validation period
#   - Validation period metrics:
#     NSE: 0.698
#     KGE: 0.775 (r=0.876, α=1.120, β=0.855)
#     KGE_NP: 0.652 (r_s=0.707, α_np=1.119, β=0.855)
#     Data points: 2193
#   ✓ Calculated metrics: NSE=0.698, KGE=0.775, KGE_NP=0.652
#
# Processing configuration: 03_model_setups_gmb_prec
# ...

# %%
param_results = postprocessing_configurations.plot_parameter_boxplots_comparison(multi_config, top_n=100)
# Out:
# Creating parameter boxplots comparison for 6 configurations:
#   - Catchment: 0118
#   - Top 100 parameter sets per configuration
# Created multi-configuration plot directory: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/multi_config_plots_catchment_0118
#
# Processing configuration: 03_model_setups_gmb
#
# ----------------------------------------
# Analyzing parameters for 0118
# ----------------------------------------
# Found calibration file: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/03_model_setups_gmb/catchment_0118/HBV/output/calibration_results_0118_HBV_20260212_144355.csv
# Loaded 2763 parameter sets
# Using 'objective' column for parameter selection
# Using objective column: objective
# Selected top 100 parameter sets
# Objective range: 0.6006 to 0.6460
# Found 16 parameter columns: HBV_RainSnow_Temp, HBV_Melt_Factor, HBV_Refreeze_Factor, HBV_Snow_SWI, HBV_Porosity...
#   ✓ Loaded 16 parameters with 100 parameter sets
#
# ...

# %%
postprocessing_configurations.plot_storage_timeseries_comparison(multi_config)
# Out:
# Creating storage timeseries comparison for 6 configurations:
#   - Catchment: 0118
#   - Validation period: 1991-12-31 to 1997-12-31
# Created multi-configuration plot directory: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/multi_config_plots_catchment_0118
#
# Processing configuration: 03_model_setups_gmb
# Loading storage data:
#   - File: /home/jberg/OneDrive/Raven_worldwide/03_model_setups_14.02/03_model_setups_gmb/catchment_0118/HBV/output/0118_HBV_WatershedStorage.csv
#   - Loaded 5478 records from 1983-01-02 00:00:00 to 1997-12-31 00:00:00
#   - Storage columns: ['rainfall [mm/day]', 'snowfall [mm/d SWE]', 'Rivulet Storage [mm]', 'Cum. Losses to Atmosphere [mm]', 'Ponded Water [mm]', 'Soil Water[0] [mm]', 'Soil Water[1] [mm]', 'Soil Water[2] [mm]', 'Snow Melt (Liquid) [mm]', 'Snow [mm]', ' Total [mm]', ' Cum. Inputs [mm]', ' Cum. Outflow [mm]', ' MB Error [mm]']
#   ✓ Loaded storage data: 2193 records, 14 components
#
# ...
